# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# prophet: facebook 에서 만든 패키지
# Tool for producing high quality forecasts for time series data that has multiple seasonality with linear or non-linear growth
# https://facebook.github.io/prophet/
from fbprophet import Prophet

# %%
df = pd.read_csv("/content/^KS11.csv")
df
# Out:
#             Date         Open         High  ...        Close    Adj Close    Volume
# 0     2000-01-04  1028.329956  1066.180054  ...  1059.040039  1059.040039  195900.0
# 1     2000-01-05  1006.869995  1026.520020  ...   986.309998   986.309998  257700.0
# 2     2000-01-06  1013.950012  1014.900024  ...   960.789978   960.789978  203500.0
# 3     2000-01-07   949.169983   970.159973  ...   948.650024   948.650024  215700.0
# 4     2000-01-10   979.669983   994.940002  ...   987.239990   987.239990  240200.0
# ...          ...          ...          ...  ...          ...          ...       ...
# 5421  2021-07-27  3244.429932  3252.850098  ...  3232.530029  3232.530029  991600.0
# 5422  2021-07-28  3226.060059  3243.209961  ...  3236.860107  3236.860107  868200.0
# 5423  2021-07-29  3248.489990  3252.260010  ...  3242.649902  3242.649902  694500.0
# 5424  2021-07-30  3234.370117  3234.659912  ...  3202.320068  3202.320068  687500.0
# 5425  2021-08-02  3218.419922  3223.040039  ...  3223.040039  3223.040039  561003.0
#
# [5426 rows x 7 columns]

# %%
data = df[['Date','Close']].reset_index(drop=True)
data = data.rename(columns={ 'Date' : 'ds', 'Close' : 'y'})
data
# Out:
#               ds            y
# 0     2000-01-04  1059.040039
# 1     2000-01-05   986.309998
# 2     2000-01-06   960.789978
# 3     2000-01-07   948.650024
# 4     2000-01-10   987.239990
# ...          ...          ...
# 5421  2021-07-27  3232.530029
# 5422  2021-07-28  3236.860107
# 5423  2021-07-29  3242.649902
# 5424  2021-07-30  3202.320068
# 5425  2021-08-02  3223.040039
#
# [5426 rows x 2 columns]

# %%
model = Prophet(daily_seasonality = True)

model.fit(data)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.

# %%
future = model.make_future_dataframe(periods = 365)
forecast = model.predict(future)
forecast.tail()
# Out:
#              ds        trend  ...  multiplicative_terms_upper         yhat
# 5786 2022-07-29  2923.011815  ...                         0.0  2751.593134
# 5787 2022-07-30  2923.337830  ...                         0.0  2780.428533
# 5788 2022-07-31  2923.663845  ...                         0.0  2777.772849
# 5789 2022-08-01  2923.989859  ...                         0.0  2743.022514
# 5790 2022-08-02  2924.315874  ...                         0.0  2741.801390
#
# [5 rows x 22 columns]

# %%
model.plot(forecast)

# %%
model.plot_components(forecast)
